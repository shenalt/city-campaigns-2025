# %%
import pandas as pd
pd.set_option('display.float_format', '{:,.2f}'.format)
#SETTING AND RESETTING DISPLAY OPTIONS
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.reset_option('display.max_rows')
#pd.reset_option('display.max_columns')

og_df = pd.read_excel('data/CityElections_2025.xlsx')
copy_df = og_df.copy()
df = og_df.copy()

df
# Out:
#        ELECTION  OFFICECD RECIPID CANCLASS             RECIPNAME COMMITTEE  \
# 0          2025         3    1682        P     Rajkumar, Jenifer         I
# 1          2025         5    2348        P    Sanchez, Pierina A         K
# 2          2025         2    1227        P   Williams, Jumaane D         R
# 3          2025         1    1164        P          Lander, Brad         N
# 4          2025         4    1190        P     Richards, Donovan         O
# ...         ...       ...     ...      ...                   ...       ...
# 85579      2025         5    2922        P  Lewinsohn, Elizabeth         H
# 85580      2025         5     504        P         Ariola, Joann         M
# 85581      2025         5    1529       UN          Menin, Julie         L
# 85582      2025         1    1545        P         Adams, Eric L         N
# 85583      2025         1    2869        P             Huq, Md M         H
#
#        FILING SCHEDULE  PAGENO  SEQUENCENO     REFNO       DATE REFUNDDATE  \
# 0           7      ABC     NaN         NaN  R0003944 2025-01-03        NaT
# 1           6      ABC     NaN         NaN  R0014053 2024-10-06        NaT
# 2           4      ABC     NaN         NaN  R0040574 2024-01-12        NaT
# 3           2      ABC     NaN         NaN  R0064837 2023-01-13        NaT
# 4           5      ABC     NaN         NaN  R0023969 2024-05-24        NaT
# ...       ...      ...     ...         ...       ...        ...        ...
# 85579       7      ABC     NaN         NaN  R0000411 2024-12-29        NaT
# 85580       5      ABC     NaN         NaN  R0008433 2024-05-18        NaT
# 85581       6      ABC     NaN         NaN  R0007840 2024-09-04        NaT
# 85582       1      ABC     NaN         NaN  R0080101 2022-04-01        NaT
# 85583       6      ABC     NaN         NaN  R0000025 2024-07-15        NaT
#
#                       NAME C_CODE  STRNO  STRNAME  APARTMENT BOROUGHCD  \
# 0                 #NA, #Na    IND    NaN      NaN        NaN         Q
# 1            2025, Selvena    IND    NaN      NaN        NaN         Q
# 2         32 BJ United ADF   EMPO    NaN      NaN        NaN         M
# 3          32BJ United ADF  PCOMP    NaN      NaN        NaN         M
# 4          32BJ United ADF  PCOMP    NaN      NaN        NaN         M
# ...                    ...    ...    ...      ...        ...       ...
# 85579  Zwillinger, Rebecca    IND    NaN      NaN        NaN         M
# 85580          Zwirn, Alan    IND    NaN      NaN        NaN         Z
# 85581    Zylberberg, David    IND    NaN      NaN        NaN         M
# 85582   Zyscovich, Bernard    IND    NaN      NaN        NaN         Z
# 85583        Zzaman, Molla    IND    NaN      NaN        NaN         Q
#
#                  CITY STATE    ZIP              OCCUPATION  \
# 0            Brooklyn    NY  11101              Unemployed
# 1      Rockaway Beach    NY  11693          Council Member
# 2            New York    NY  10011                     NaN
# 3            New York    NY  10011                     NaN
# 4            New York    NY  10011                     NaN
# ...               ...   ...    ...                     ...
# 85579        New York    NY  10028               Homemaker
# 85580   Boynton Beach    FL  33437                 Retired
# 85581        New York    NY  10128                Attorney
# 85582           Miami    FL  33132               Architect
# 85583         Jamaica    NY  11432  Financial professional
#
#                               EMPNAME EMPSTRNO           EMPSTRNAME  \
# 0                                 NaN      NaN                  NaN
# 1                         NYC Council    79-14  Rockaway Beach Blvd
# 2                                 NaN      NaN                  NaN
# 3                                 NaN      NaN                  NaN
# 4                                 NaN      NaN                  NaN
# ...                               ...      ...                  ...
# 85579                             NaN      NaN                  NaN
# 85580                             NaN      NaN                  NaN
# 85581  Simpson Thacher & Bartlett LLP      425     Lexington Avenue
# 85582                 Zyscovich-Owner      100        Biscayne Blvd
# 85583                   Self-Employed    85-02         169 streetNy
#
#               EMPCITY EMPSTATE     AMNT  MATCHAMNT  PREVAMNT  PAY_METHOD  \
# 0                 NaN      NaN   250.00          0      0.00           4
# 1      Rockaway Beach       NY 1,050.00          0      0.00           4
# 2                 NaN      NaN 2,100.00          0      0.00           2
# 3                 NaN      NaN 2,100.00          0      0.00           2
# 4                 NaN      NaN 1,600.00          0      0.00           2
# ...               ...      ...      ...        ...       ...         ...
# 85579             NaN      NaN   150.00        150      0.00           4
# 85580             NaN      NaN    25.00          0      0.00           4
# 85581        New York       NY    10.00          0      0.00           4
# 85582           Miami       FL   400.00          0      0.00           4
# 85583         Jamaica       NY    10.00         10      0.00           4
#
#        INTERMNO INTERMNAME  INTSTRNO  INTSTRNM  INTAPTNO INTCITY INTST  \
# 0           NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 1           NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 2           NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 3           NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 4           NaN        NaN       NaN       NaN       NaN     NaN   NaN
# ...         ...        ...       ...       ...       ...     ...   ...
# 85579       NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 85580       NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 85581       NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 85582       NaN        NaN       NaN       NaN       NaN     NaN   NaN
# 85583       NaN        NaN       NaN       NaN       NaN     NaN   NaN
#
#        INTZIP INTEMPNAME INTEMPSTNO INTEMPSTNM INTEMPCITY INTEMPST INTOCCUPA  \
# 0         NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 1         NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 2         NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 3         NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 4         NaN        NaN        NaN        NaN        NaN      NaN       NaN
# ...       ...        ...        ...        ...        ...      ...       ...
# 85579     NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 85580     NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 85581     NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 85582     NaN        NaN        NaN        NaN        NaN      NaN       NaN
# 85583     NaN        NaN        NaN        NaN        NaN      NaN       NaN
#
#       PURPOSECD EXEMPTCD  ADJTYPECD RR_IND SEG_IND INT_C_CODE
# 0           NaN      NaN        NaN      N       N        NaN
# 1           NaN      NaN        NaN      N       N        NaN
# 2           NaN      NaN        NaN      N       N        NaN
# 3           NaN      NaN        NaN      N       N        NaN
# 4           NaN      NaN        NaN      N       N        NaN
# ...         ...      ...        ...    ...     ...        ...
# 85579       NaN      NaN        NaN      N       N        NaN
# 85580       NaN      NaN        NaN      N       N        NaN
# 85581       NaN      NaN        NaN      N       N        NaN
# 85582       NaN      NaN        NaN      N       N        NaN
# 85583       NaN      NaN        NaN      N       N        NaN
#
# [85584 rows x 52 columns]

# %%
#CLEANING TIME
df.isnull().sum()
# Out:
# ELECTION          0
# OFFICECD          0
# RECIPID           0
# CANCLASS          0
# RECIPNAME         0
# COMMITTEE         0
# FILING            0
# SCHEDULE          0
# PAGENO        85584
# SEQUENCENO    85584
# REFNO             0
# DATE             22
# REFUNDDATE    84427
# NAME              0
# C_CODE            0
# STRNO         85584
# STRNAME       85584
# APARTMENT     85584
# BOROUGHCD       121
# CITY             65
# STATE           142
# ZIP              91
# OCCUPATION     4660
# EMPNAME       13165
# EMPSTRNO      19830
# EMPSTRNAME    19618
# EMPCITY       19291
# EMPSTATE      19137
# AMNT              0
# MATCHAMNT         0
# PREVAMNT          0
# PAY_METHOD        0
# INTERMNO      83545
# INTERMNAME    83545
# INTSTRNO      85584
# INTSTRNM      85584
# INTAPTNO      85584
# INTCITY       83552
# INTST         83552
# INTZIP        83552
# INTEMPNAME    83767
# INTEMPSTNO    83880
# INTEMPSTNM    83879
# INTEMPCITY    83879
# INTEMPST      83879
# INTOCCUPA     83725
# PURPOSECD     85421
# EXEMPTCD      85579
# ADJTYPECD     84427
# RR_IND            0
# SEG_IND         163
# INT_C_CODE    83545
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0
